# %% [markdown]
# <a href="https://colab.research.google.com/github/E1250/Feature-Engineering-Dr-Hesham-Asem/blob/main/Data_Cleaning_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Cleaning in Python
# Applying of YT Data Cleaning Video : https://www.youtube.com/watch?v=vPaXbA_xQFQ
# Which in DR: Hesham Asem Featrue Engineering Course

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Loading & Reading Files

# %% [markdown]
# ### The first Problem we faced Here is wrong Encoding

# %%
df = pd.read_csv("/content/unclean_data.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-19-236fe8d5ac2d> in <module>
# ----> 1 df = pd.read_csv("/content/unclean_data.csv")
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# #### First Solution is to change the encoding
# #### Another Solution is to open it in an editor and save it in another encode

# %%
# the solution
df = pd.read_csv("/content/unclean_data.csv",encoding= 'latin1')
df.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %% [markdown]
# ### Inconsistent Column Names

# %%
df.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
# Uppercase Columns name and save them 
df.columns = df.columns.str.upper()

# %% [markdown]
# #### Rename Columns

# %%
# df.rename(columns= {'old name':'new name'})
df.rename(columns= {'DURATION':'TIME'}).head()
# Out:
#                                   MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS   TIME  \
# 0                                    Avatar?ÿ                     723  178.0
# 1  Pirates of the Caribbean: At World's End?ÿ                     302    NaN
# 2                                   Spectre?ÿ                     602  148.0
# 3                     The Dark Knight Rises?ÿ                     813    NaN
# 4                               John Carter?ÿ                     462  132.0
#
#   DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  ACTOR_1_FACEBOOK_LIKES  \
# 0                      10                     855                    1000
# 1                     563                    1000                   40000
# 2                      20                     161                   11000
# 3                   22000                   23000                   27000
# 4                   "475"                     530                     640
#
# ...

# %% [markdown]
# ### Missing Data

# %%
df.isnull().sum()
# Out:
# MOVIE_TITLE                  0
# NUM_CRITIC_FOR_REVIEWS       0
# DURATION                     3
# DIRECTOR_FACEBOOK_LIKES      2
# ACTOR_3_FACEBOOK_LIKES       0
# ACTOR_1_FACEBOOK_LIKES       0
# GROSS                        0
# NUM_VOTED_USERS              1
# CAST_TOTAL_FACEBOOK_LIKES    2
# FACENUMBER_IN_POSTER         5
# NUM_USER_FOR_REVIEWS         0
# BUDGET                       0
# TITLE_YEAR                   0
# ACTOR_2_FACEBOOK_LIKES       1
# IMDB_SCORE                   0
# TITLE_YEAR.1                 7
# dtype: int64

# %%
df.isnull().any()
# Out:
# MOVIE_TITLE                  False
# NUM_CRITIC_FOR_REVIEWS       False
# DURATION                      True
# DIRECTOR_FACEBOOK_LIKES       True
# ACTOR_3_FACEBOOK_LIKES       False
# ACTOR_1_FACEBOOK_LIKES       False
# GROSS                        False
# NUM_VOTED_USERS               True
# CAST_TOTAL_FACEBOOK_LIKES     True
# FACENUMBER_IN_POSTER          True
# NUM_USER_FOR_REVIEWS         False
# BUDGET                       False
# TITLE_YEAR                   False
# ACTOR_2_FACEBOOK_LIKES        True
# IMDB_SCORE                   False
# TITLE_YEAR.1                  True
# dtype: bool

# %% [markdown]
# #### Dealing with Null Data

# %%
# with fillna
clean = df.fillna(0)
clean.head()
# Out:
#                                   MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    DURATION DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# 0     178.0                      10                     855
# 1       0.0                     563                    1000
# 2     148.0                      20                     161
# 3       0.0                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_FACEBOOK_LIKES      GROSS  NUM_VOTED_USERS  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
#With mean
cleaned_mean = df.DURATION.fillna(df['DURATION'].mean())
cleaned_mean.head()
# Out:
# 0    178.000000
# 1    150.727273
# 2    148.000000
# 3    150.727273
# 4    132.000000
# Name: DURATION, dtype: float64

# %%
cleaned_mean.isnull().any().any()
# Out:
# False

# %%
df.shape
# Out:
# (14, 16)

# %%
# dropping all null values
df_drop = df.dropna()
df_drop.head()
# Out:
#                                      MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 2                                      Spectre?ÿ                     602
# 8                      Avengers: Age of Ultron?ÿ                     635
# 12                           Quantum of Solace?ÿ                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                     313
#
#     DURATION DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# 2      148.0                      20                     161
# 8      141.0                      10                   19000
# 12     106.0                     395                     393
# 13     151.0                     563                    1000
#
#     ACTOR_1_FACEBOOK_LIKES      GROSS  NUM_VOTED_USERS  \
# 2                    11000  200074175         275868.0
# 8                    26000  458991599         462669.0
# 12                     451  168368427         330784.0
# 13                   40000  423032628         522040.0
#
# ...

# %%
# ?df.dropna

# %%
df_drop = df.dropna(how = 'any',thresh=1)
df_drop.head()
# Out:
#                                   MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    DURATION DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_FACEBOOK_LIKES      GROSS  NUM_VOTED_USERS  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %% [markdown]
# ### Dealing with Dupliates
